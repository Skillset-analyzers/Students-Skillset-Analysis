# %% [markdown]
# <a href="https://colab.research.google.com/github/kushagrathisside/Students-Skillset-Analysis/blob/main/De_Anonymising_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Student_Survey.csv')
df.head()
# Out:
#                         Timestamp               1. Name 2.Gender  \
# 0  2022/12/16 2:15:06 AM GMT+5:30   Kushagra Srivastava     Male
# 1  2022/12/16 7:43:31 AM GMT+5:30        Radhika Gupta    Female
# 2  2022/12/16 9:12:46 AM GMT+5:30  Rudransh Srivastava      Male
# 3  2022/12/16 9:14:05 AM GMT+5:30      Shiv Srivastava      Male
# 4  2022/12/16 9:14:49 AM GMT+5:30           Sahil bisht     Male
#
#   3. Year of Study 4. Branch               5. KIET E-mail Id  \
# 0            Third    CSE/IT   kushagra.2024cse1172@kiet.edu
# 1           Second      CSIT  radhika.2125csit1147@kiet.edu
# 2           Second      CSIT      rudransh.2125csit@kiet.edu
# 3           Second      CSIT      shiv.2125csit1121@kiet.edu
# 4           Second      CSIT     sahil.2125csit1057@kiet.edu
#
#   6. I Would like to participate in the Research work in Future.  \
# 0                                                Yes
# 1                                                 No
# ...

# %% [markdown]
# Working on data, finding identity related features

# %%
df.columns
# Out:
# Index(['Timestamp', '1. Name', '2.Gender', '3. Year of Study', '4. Branch',
#        '5. KIET E-mail Id',
#        '6. I Would like to participate in the Research work in Future.',
#        '1. Type of Schooling till 10th Grade:', '2. Percentage in Class 10th?',
#        '3. Location of Class 10th School:',
#        '4. Type of Schooling for class 12th:', '5. Percentage in Class 12th?',
#        '6. Location of Class 12th School:', '7. Dropped an year after School?',
#        '8. Are you about to become first generation graduate ?',
#        '9. Involved in additional volunteer groups?(NCC,NSS, Social Welfare Groups  or any other)',
#        '1. How many programming languages do you know? ',
#        '2.  Actively involved in Specific technology?',
#        '3. Exposure to Data structure and algorithms?',
#        '4. Exposure to GitHub ?',
#        '5. Are you associated with any developer Community?',
#        '6. Active in developer Communities',
# ...

# %% [markdown]
# Dropping the features

# %%
df=df.drop(['Timestamp'],axis=1)
df=df.drop(['1. Name'],axis=1)
df=df.drop(['5. KIET E-mail Id'],axis=1)
df=df.drop(['6. I Would like to participate in the Research work in Future.'],axis=1)

# %%
df
# Out:
#     2.Gender 3. Year of Study 4. Branch 1. Type of Schooling till 10th Grade:  \
# 0       Male            Third    CSE/IT                      Normal Schooling
# 1     Female           Second      CSIT               Schooling with Tuitions
# 2       Male           Second      CSIT                      Normal Schooling
# 3       Male           Second      CSIT                      Normal Schooling
# 4       Male           Second      CSIT                      Normal Schooling
# ..       ...              ...       ...                                   ...
# 251   Female            Third       CSE               Schooling with Tuitions
# 252     Male           Second       ECE                      Normal Schooling
# 253     Male           Second      CSIT                      Normal Schooling
# 254     Male           Second       ECE                      Normal Schooling
# 255     Male           Second       MCA                      Normal Schooling
#
# ...

# %% [markdown]
# Downloading the csv file

# %%
csv_data = df.to_csv('Studentdata.csv', index = True)
