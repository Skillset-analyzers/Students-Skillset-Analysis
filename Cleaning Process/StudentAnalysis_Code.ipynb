# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Fetching the csv file
df= pd.read_csv("/content/sample_data/Student Survey (Responses) - Form Responses 1.csv")
df
# Out:
#                Timestamp               1. Name 2.Gender 3. Year of Study  \
# 0     12/16/2022 2:15:06   Kushagra Srivastava     Male            Third
# 1     12/16/2022 7:43:31        Radhika Gupta    Female           Second
# 2     12/16/2022 9:12:46  Rudransh Srivastava      Male           Second
# 3     12/16/2022 9:14:06      Shiv Srivastava      Male           Second
# 4     12/16/2022 9:14:49           Sahil bisht     Male           Second
# ..                   ...                   ...      ...              ...
# 251  12/16/2022 18:18:43         Samaira Singh   Female            Third
# 252  12/16/2022 18:19:01       Prakhar Parmar      Male           Second
# 253  12/16/2022 18:21:26         Aman Dwivedi      Male           Second
# 254  12/16/2022 18:44:36       Kushagra Singh      Male           Second
# 255  12/16/2022 18:50:02        Nikhil Kaushik     Male           Second
#
#     4. Branch               5. KIET E-mail Id  \
# ...

# %%
# Checking the shape of the file
df.shape
# Out:
# (256, 28)

# %%
# Printing the top five and bottom five rows in order to visualize the data
df.head()
# Out:
#             Timestamp               1. Name 2.Gender 3. Year of Study  \
# 0  12/16/2022 2:15:06   Kushagra Srivastava     Male            Third
# 1  12/16/2022 7:43:31        Radhika Gupta    Female           Second
# 2  12/16/2022 9:12:46  Rudransh Srivastava      Male           Second
# 3  12/16/2022 9:14:06      Shiv Srivastava      Male           Second
# 4  12/16/2022 9:14:49           Sahil bisht     Male           Second
#
#   4. Branch               5. KIET E-mail Id  \
# 0    CSE/IT   kushagra.2024cse1172@kiet.edu
# 1      CSIT  radhika.2125csit1147@kiet.edu
# 2      CSIT      rudransh.2125csit@kiet.edu
# 3      CSIT      shiv.2125csit1121@kiet.edu
# 4      CSIT     sahil.2125csit1057@kiet.edu
#
#   6. I Would like to participate in the Research work in Future.  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# ...

# %%
df.tail()
# Out:
#                Timestamp          1. Name 2.Gender 3. Year of Study 4. Branch  \
# 251  12/16/2022 18:18:43    Samaira Singh   Female            Third       CSE
# 252  12/16/2022 18:19:01  Prakhar Parmar      Male           Second       ECE
# 253  12/16/2022 18:21:26    Aman Dwivedi      Male           Second      CSIT
# 254  12/16/2022 18:44:36  Kushagra Singh      Male           Second       ECE
# 255  12/16/2022 18:50:02   Nikhil Kaushik     Male           Second       MCA
#
#                 5. KIET E-mail Id  \
# 251  samaira.2024cse1017@kiet.edu
# 252  prakhar.2125ec1106@kiet.edu
# 253    aman.2125csit1062@kiet.edu
# 254  kushagra.2125ec1122@kiet.edu
# 255   nikhil.2124mca1003@kiet.edu
#
#     6. I Would like to participate in the Research work in Future.  \
# 251                                                Yes
# 252                                                Yes
# 253                                                Yes
# ...

# %%
df.describe()
# Out:
#                  Timestamp              1. Name 2.Gender 3. Year of Study  \
# count                  256                  256      256              256
# unique                 251                  256        2                3
# top     12/16/2022 9:36:03  Kushagra Srivastava     Male           Second
# freq                     2                    1      191              198
#
#        4. Branch              5. KIET E-mail Id  \
# count        256                            256
# unique        12                            256
# top         CSIT  kushagra.2024cse1172@kiet.edu
# freq          58                              1
#
#        6. I Would like to participate in the Research work in Future.  \
# count                                                 256
# unique                                                  2
# top                                                   Yes
# freq                                                  223
#
# ...

# %%
# Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 28 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Timestamp                                                                                  256 non-null    object
#  1   1. Name                                                                                    256 non-null    object
#  2   2.Gender                                                                                   256 non-null    object
#  3   3. Year of Study                                                                           256 non-null    object
#  4   4. Branch                                                                                  256 non-null    object
# ...

# %%
# To check if there are any null values in the dataset
df.isnull()
# Out:
#      Timestamp  1. Name  2.Gender  3. Year of Study  4. Branch  \
# 0        False    False     False             False      False
# 1        False    False     False             False      False
# 2        False    False     False             False      False
# 3        False    False     False             False      False
# 4        False    False     False             False      False
# ..         ...      ...       ...               ...        ...
# 251      False    False     False             False      False
# 252      False    False     False             False      False
# 253      False    False     False             False      False
# 254      False    False     False             False      False
# 255      False    False     False             False      False
#
#      5. KIET E-mail Id  \
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 251              False
# ...

# %%
# Total null values in each column
df.isnull().sum()
# Out:
# Timestamp                                                                                     0
# 1. Name                                                                                       0
# 2.Gender                                                                                      0
# 3. Year of Study                                                                              0
# 4. Branch                                                                                     0
# 5. KIET E-mail Id                                                                             0
# 6. I Would like to participate in the Research work in Future.                                0
# 1. Type of Schooling till 10th Grade:                                                         0
# 2. Percentage in Class 10th?                                                                  0
# 3. Location of Class 10th School:                                                             0
# ...

# %%
df.drop('1. Name', inplace=True , axis=1)

# %%
df.drop('Timestamp', inplace=True, axis=1)

# %%
df.drop('5. KIET E-mail Id', inplace=True, axis=1)

# %%
# Removed the coulmns which are not necessary
df
# Out:
#     2.Gender 3. Year of Study 4. Branch  \
# 0       Male            Third    CSE/IT
# 1     Female           Second      CSIT
# 2       Male           Second      CSIT
# 3       Male           Second      CSIT
# 4       Male           Second      CSIT
# ..       ...              ...       ...
# 251   Female            Third       CSE
# 252     Male           Second       ECE
# 253     Male           Second      CSIT
# 254     Male           Second       ECE
# 255     Male           Second       MCA
#
#     6. I Would like to participate in the Research work in Future.  \
# 0                                                  Yes
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 251                                                Yes
# ...

# %%
# New information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 25 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   2.Gender                                                                                   256 non-null    object
#  1   3. Year of Study                                                                           256 non-null    object
#  2   4. Branch                                                                                  256 non-null    object
#  3   6. I Would like to participate in the Research work in Future.                             256 non-null    object
#  4   1. Type of Schooling till 10th Grade:                                                      256 non-null    object
# ...

# %%
# Heatmap of the dataset using seaborn library
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())

# %%
# Setting the null values as string "No"
df["6. Active in developer Communities"].fillna("No ", inplace = True)

# %%
# After removing Null Values from the particular column
df.isnull().sum()
# Out:
# 2.Gender                                                                                     0
# 3. Year of Study                                                                             0
# 4. Branch                                                                                    0
# 6. I Would like to participate in the Research work in Future.                               0
# 1. Type of Schooling till 10th Grade:                                                        0
# 2. Percentage in Class 10th?                                                                 0
# 3. Location of Class 10th School:                                                            0
# 4. Type of Schooling for class 12th:                                                         0
# 5. Percentage in Class 12th?                                                                 0
# 6. Location of Class 12th School:                                                            0
# ...

# %%
# Cleaned dataset
df.to_csv("Cleaned dataset.csv")
